# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load datasets for modeling

# %%
from google.colab import drive
drive.mount('/content/drive')

premodel_core = pd.read_csv("/content/drive/MyDrive/MDP_Capstone_Project/Data/Model_Core_Final.csv")
premodel_gust = pd.read_csv("/content/drive/MyDrive/MDP_Capstone_Project/Data/Model_Gust_Final.csv")
# Out:
# Mounted at /content/drive
# /tmp/ipython-input-399/274579847.py:5: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   premodel_gust = pd.read_csv("/content/drive/MyDrive/MDP_Capstone_Project/Data/Model_Gust_Final.csv")

# %% [markdown]
# ### Quick dataset checks

# %%
print("Core Shape:", premodel_core.shape)
print("Gust Shape:", premodel_gust.shape)
print("Core Class Balance Check:", premodel_core["High_Intensity"].value_counts(normalize=True))
print("Gust Class Balance Check:", premodel_gust["High_Intensity"].value_counts(normalize=True))
# Out:
# Core Shape: (1563080, 21)
# Gust Shape: (1011445, 25)
# Core Class Balance Check: High_Intensity
# 0    0.900896
# 1    0.099104
# Name: proportion, dtype: float64
# Gust Class Balance Check: High_Intensity
# 0    0.886772
# 1    0.113228
# Name: proportion, dtype: float64

# %%
premodel_core["LC_Type1"] = premodel_core["LC_Type1"].astype("category")
premodel_gust["LC_Type1"] = premodel_gust["LC_Type1"].astype("category")

print(premodel_core.dtypes)
print(premodel_gust.dtypes)
# Out:
# High_Intensity                     int64
# Mean_Temp_C                      float64
# Total_Precip_mm                  float64
# LC_Type1                        category
# Month                              int64
# Day_of_Year                        int64
# Latitude_Fire                    float64
# Longitude_Fire                   float64
# Elevation_m                      float64
# FRP_max                          float64
# Fire_ID                            int64
# Climate_ID                        object
# LC_Label                          object
# Nearest_Core_Station_Dist_km     float64
# Core_Dist_75km                      bool
# Core_Dist_100km                     bool
# Confidence_Ordered                 int64
# DayNight                          object
# Hour                               int64
# Year                               int64
# Province                          object
# dtype: object
# High_Intensity                     int64
# Mean_Temp_C                      float64
# Total_Precip_mm                  float64
# Max_Gust_Speed_kmh               float64
# LC_Type1                        category
# Month                              int64
# Day_of_Year                        int64
# Latitude_Fire                    float64
# Longitude_Fire                   float64
# Elevation_m                      float64
# FRP_max                          float64
# Fire_ID                            int64
# Climate_ID                        object
# LC_Label                          object
# Gust_Flag_Threshold                 bool
# Gust_Flag_Imputed                   bool
# Imputed_Radius_km                float64
# Nearest_Gust_Station_Dist_km     float64
# Gust_Dist_75km                      bool
# Gust_Dist_100km                     bool
# Confidence_Ordered                 int64
# DayNight                          object
# Hour                               int64
# Year                               int64
# Province                          object
# dtype: object

# %% [markdown]
# # **1. RANDOM FOREST FOR CORE DATASET (Spatial Features Removed)**

# %% [markdown]
# ## **(1) Define Features and Response**

# %%
# Core feature set for baseline model
core_features = [
    "Mean_Temp_C",
    "Total_Precip_mm",
    "Elevation_m",
    "Month",
    "Day_of_Year",
    "LC_Type1"
]

X = premodel_core[core_features].copy()
y = premodel_core["High_Intensity"].copy()

# %% [markdown]
# ### **(2) Define Train/Test Split**

# %%
from sklearn.model_selection import train_test_split

# Startified split to ensure rare high-intensity class representation
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=123,
    stratify=y
)

# %% [markdown]
# ### **(3) Feature Adjustment Preprocessing**

# %%
# Define feature types (numerical and categorical)
numeric_features = [
    "Mean_Temp_C",
    "Total_Precip_mm",
    "Elevation_m",
    "Month",
    "Day_of_Year"
]

categorical_features = ["LC_Type1"]

# %% [markdown]
# ### Construct preprocessing and model pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# No scaling for numeric, only encoding for land cover
preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# Input random forest model parameters
RF = RandomForestClassifier(
    n_estimators=300,
    random_state=123,
    n_jobs=-1,
    class_weight="balanced_subsample",
    min_samples_leaf=5
)

# Define pipeline
pipeline = Pipeline(
    steps=[("preprocess", preprocess), ("model", RF)]
)

# %% [markdown]
# ### **(4) Fit Model & Evaluate Performance**

# %%
# Fit the model
pipeline.fit(X_train, y_train)

# Evaluate Performance
y_pred = pipeline.predict(X_test)
y_prob = pipeline.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC–AUC:", roc_auc_score(y_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81    281634
#            1       0.22      0.76      0.34     30982
#
#     accuracy                           0.71    312616
#    macro avg       0.59      0.73      0.57    312616
# weighted avg       0.89      0.71      0.76    312616
#
# ROC–AUC: 0.8053569390828305
# Confusion Matrix:
#  [[197137  84497]
#  [  7494  23488]]

# %% [markdown]
# ### **(5) Feature Importance Table**

# %%
# Get feature names after preprocessing
feature_names = pipeline.named_steps["preprocess"].get_feature_names_out()
importances = pipeline.named_steps["model"].feature_importances_

FI = (pd.DataFrame({"Feature": feature_names, "Importance": importances})
        .sort_values("Importance", ascending=False)
        .reset_index(drop=True))

FI.head(20)
# Out:
#                  Feature  Importance
# 0       num__Mean_Temp_C    0.324071
# 1       num__Day_of_Year    0.295430
# 2       num__Elevation_m    0.219223
# 3   num__Total_Precip_mm    0.058086
# 4             num__Month    0.048408
# 5        cat__LC_Type1_8    0.012662
# 6        cat__LC_Type1_1    0.009572
# 7        cat__LC_Type1_5    0.008032
# 8        cat__LC_Type1_9    0.006255
# 9       cat__LC_Type1_10    0.004826
# 10      cat__LC_Type1_12    0.003585
# 11      cat__LC_Type1_13    0.003217
# 12      cat__LC_Type1_16    0.003167
# 13      cat__LC_Type1_11    0.000996
# 14       cat__LC_Type1_7    0.000887
# 15      cat__LC_Type1_17    0.000506
# 16       cat__LC_Type1_4    0.000407
# 17      cat__LC_Type1_14    0.000289
# 18       cat__LC_Type1_3    0.000282
# 19       cat__LC_Type1_2    0.000098

# %% [markdown]
# # **2. RANDOM FOREST FOR GUST DATASET (Spatial Features Removed)**

# %% [markdown]
# ## **(1) Define Features and Response**

# %%
# Gust feature set for baseline model
gust_features = [
    "Mean_Temp_C",
    "Total_Precip_mm",
    "Max_Gust_Speed_kmh",
    "Elevation_m",
    "Month",
    "Day_of_Year",
    "LC_Type1"
]

X = premodel_gust[gust_features].copy()
y = premodel_gust["High_Intensity"].copy()

# %% [markdown]
# ### **(2) Define Train/Test Split**

# %%
from sklearn.model_selection import train_test_split

# Startified split to ensure rare high-intensity class representation
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=123,
    stratify=y
)

# %% [markdown]
# ### **(3) Feature Adjustment Preprocessing**

# %%
# Define feature types (numerical and categorical)
numeric_features = [
    "Mean_Temp_C",
    "Total_Precip_mm",
    "Max_Gust_Speed_kmh",
    "Elevation_m",
    "Month",
    "Day_of_Year"
]

categorical_features = ["LC_Type1"]

# %% [markdown]
# ### Construct preprocessing and model pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# No scaling for numeric, only encoding for land cover
preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# Input random forest model parameters
RF = RandomForestClassifier(
    n_estimators=300,
    random_state=123,
    n_jobs=-1,
    class_weight="balanced_subsample",
    min_samples_leaf=5
)

# Define pipeline
pipeline = Pipeline(
    steps=[("preprocess", preprocess), ("model", RF)]
)

# %% [markdown]
# ### **(4) Fit Model & Evaluate Performance**

# %%
# Fit the model
pipeline.fit(X_train, y_train)

# Evaluate Performance
y_pred = pipeline.predict(X_test)
y_prob = pipeline.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC–AUC:", roc_auc_score(y_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80    179384
#            1       0.24      0.75      0.36     22905
#
#     accuracy                           0.70    202289
#    macro avg       0.60      0.72      0.58    202289
# weighted avg       0.87      0.70      0.75    202289
#
# ROC–AUC: 0.795196361823771
# Confusion Matrix:
#  [[124139  55245]
#  [  5772  17133]]

# %% [markdown]
# ### **(5) Feature Importance Table**

# %%
# Get feature names after preprocessing
feature_names = pipeline.named_steps["preprocess"].get_feature_names_out()
importances = pipeline.named_steps["model"].feature_importances_

FI = (pd.DataFrame({"Feature": feature_names, "Importance": importances})
        .sort_values("Importance", ascending=False)
        .reset_index(drop=True))

FI.head(20)
# Out:
#                     Feature  Importance
# 0          num__Mean_Temp_C    0.254517
# 1          num__Day_of_Year    0.234103
# 2          num__Elevation_m    0.183156
# 3   num__Max_Gust_Speed_kmh    0.152521
# 4      num__Total_Precip_mm    0.066122
# 5                num__Month    0.047294
# 6           cat__LC_Type1_8    0.015064
# 7           cat__LC_Type1_1    0.012647
# 8           cat__LC_Type1_5    0.007276
# 9           cat__LC_Type1_9    0.006677
# 10         cat__LC_Type1_10    0.006472
# 11         cat__LC_Type1_12    0.004067
# 12         cat__LC_Type1_16    0.003019
# 13         cat__LC_Type1_13    0.002915
# 14         cat__LC_Type1_11    0.001345
# 15          cat__LC_Type1_7    0.000784
# 16         cat__LC_Type1_17    0.000717
# 17          cat__LC_Type1_4    0.000645
# 18          cat__LC_Type1_3    0.000286
# 19         cat__LC_Type1_14    0.000189
